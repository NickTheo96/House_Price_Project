# %%
import simplemachinelearning as sml
import pandas as pd

from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.kernel_ridge import KernelRidge
from sklearn.linear_model import Ridge

# %matplotlib inline

# %% [markdown]
# # 1) Load In The Data From The CSV File

# %%
my_train = "/Users/nick/Desktop/train.csv"
my_test = "/Users/nick/Desktop/test.csv"
model_house = sml.DataModeler(pd.read_csv(my_train), pd.read_csv(my_test))
# Out:
# <simplemachinelearning.Class_Data_Modeler.DataModeler object at 0x110b8c7b8> created

# %% [markdown]
# # 2) Explore The Data

# %% [markdown]
# Dimension of the data:

# %%
print("The dimension of the train is: ", model_house._train_data_set.shape, 'and the dimension of the test is: ',  model_house._test_data_set.shape)
# Out:
# The dimension of the train is:  (1460, 81) and the dimension of the test is:  (1459, 80)

# %% [markdown]
# Look through the data:

# %%
print(model_house._train_data_set.head())
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# Look at missing Values

# %%
model_house.train_missing_data_ratio_print()
model_house.test_missing_data_ratio_print()
model_house.missing_data_ratio_bar_graph()
# Out:
#               Percentage of missing values in train
# PoolQC                                    99.520548
# MiscFeature                               96.301370
# Alley                                     93.767123
# Fence                                     80.753425
# FireplaceQu                               47.260274
# LotFrontage                               17.739726
# GarageYrBlt                                5.547945
# GarageType                                 5.547945
# GarageFinish                               5.547945
# GarageQual                                 5.547945
# GarageCond                                 5.547945
# BsmtFinType2                               2.602740
# BsmtExposure                               2.602740
# BsmtFinType1                               2.534247
# BsmtCond                                   2.534247
# BsmtQual                                   2.534247
# MasVnrArea                                 0.547945
# ...

# %% [markdown]
# Heat Map to see what i

# %%
model_house.heat_map()

# %%
model_house.box_plot('SalePrice', 'YearBuilt')

# %% [markdown]
# Example Bar Graph:

# %%
model_house.bar_graph_attribute('YrSold')

# %% [markdown]
# Example Line Graph:

# %%
model_house.line_graph_percentage_difference('YrSold')

# %% [markdown]
# Example Scatter Plot

# %%
model_house.scatter_plot('SalePrice', 'GrLivArea')

# %% [markdown]
# Deleting the outliers and replotting the graph

# %%
model_house.drop_outliers_target_less_y_attribute_greater_x('SalePrice', 300000, 'GrLivArea', 4000)
model_house.drop_outliers_target_greater_y_attribute_greater_x('SalePrice', 200000, 'LotFrontage', 300)
model_house.scatter_plot('SalePrice', 'GrLivArea')
